# %% [markdown]
# # Jour 5 : Fichiers et gestion des erreurs `(pas hyper important car simplifié avec Pandas)`
# ## 1) Lire un fichier texte

# %%
f = open("data.txt", "r") # Ouvrir le fichier txt en mode read ("r")
contenu = f.read()
f.close()
# Pas top en cas d'erreur

# %%
with open("data.txt", "r") as file:
    contenu = f.read()
# C'est mieux car fichier automatiquement fermé à la fin

# %%
with open("data.txt", "r") as file:
    for ligne in f:
        print(ligne.strip()) # La méthode ".split" enlève les \0 au début et à la fin du string

# %% [markdown]
# ## 2) Ecrire dans un fichier

# %%
# Ecriture dans le fichier (écrase)
with open("resultat.txt", "w") as f:
    f.write("Bonjour\n")

# Ajout d'une ligne (append)
with open("resultat.txt", "a") as f:
    f.write("Nouvelle ligne\n")
